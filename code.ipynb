# %% [markdown]
# # code

# %% [markdown]
# ## Install Dependencies

# %%
# Install required packages
# !pip install opensearch-py spacy dateparser geopy bs4 lxml tqdm

# Download spaCy English model
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: opensearch-py in c:\users\user\anaconda3\lib\site-packages (3.1.0)
# Requirement already satisfied: spacy in c:\users\user\anaconda3\lib\site-packages (3.8.11)
# Requirement already satisfied: dateparser in c:\users\user\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: geopy in c:\users\user\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: bs4 in c:\users\user\anaconda3\lib\site-packages (0.0.2)
# Requirement already satisfied: lxml in c:\users\user\anaconda3\lib\site-packages (5.3.0)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (4.67.1)
# Requirement already satisfied: urllib3!=2.2.0,!=2.2.1,<3,>=1.26.19 in c:\users\user\anaconda3\lib\site-packages (from opensearch-py) (1.26.20)
# Requirement already satisfied: requests<3.0.0,>=2.32.0 in c:\users\user\anaconda3\lib\site-packages (from opensearch-py) (2.32.3)
# Requirement already satisfied: python-dateutil in c:\users\user\anaconda3\lib\site-packages (from opensearch-py) (2.9.0.post0)
# Requirement already satisfied: certifi>=2024.07.04 in c:\users\user\anaconda3\lib\site-packages (from opensearch-py) (2025.8.3)
# Requirement already satisfied: Events in c:\users\user\anaconda3\lib\site-packages (from opensearch-py) (0.5)
# Requirement already satisfied: opensearch-protobufs==0.19.0 in c:\users\user\anaconda3\lib\site-packages (from opensearch-py) (0.19.0)
# Requirement already satisfied: protobuf>=3.20.3 in c:\users\user\anaconda3\lib\site-packages (from opensearch-protobufs==0.19.0->opensearch-py) (5.29.3)
# Requirement already satisfied: grpcio>=1.68.1 in c:\users\user\anaconda3\lib\site-packages (from opensearch-protobufs==0.19.0->opensearch-py) (1.76.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.0->opensearch-py) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.0->opensearch-py) (3.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\user\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\user\anaconda3\lib\site-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in c:\users\user\anaconda3\lib\site-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (0.20.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.1.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.10.3)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from spacy) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (24.2)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\user\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\user\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\user\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\user\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in c:\users\user\anaconda3\lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\user\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\user\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (7.5.0)
# Requirement already satisfied: wrapt in c:\users\user\anaconda3\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (1.17.0)
# Requirement already satisfied: pytz>=2024.2 in c:\users\user\anaconda3\lib\site-packages (from dateparser) (2025.2)
# Requirement already satisfied: regex>=2024.9.11 in c:\users\user\anaconda3\lib\site-packages (from dateparser) (2024.11.6)
# Requirement already satisfied: tzlocal>=0.2 in c:\users\user\anaconda3\lib\site-packages (from dateparser) (5.3.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\user\anaconda3\lib\site-packages (from geopy) (2.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil->opensearch-py) (1.17.0)
# Requirement already satisfied: tzdata in c:\users\user\anaconda3\lib\site-packages (from tzlocal>=0.2->dateparser) (2025.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->spacy) (3.0.2)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 1.5 MB/s eta 0:00:09
#      - -------------------------------------- 0.5/12.8 MB 1.5 MB/s eta 0:00:09
#      --- ------------------------------------ 1.0/12.8 MB 1.2 MB/s eta 0:00:11
#      --- ------------------------------------ 1.0/12.8 MB 1.2 MB/s eta 0:00:11
#      ---- ----------------------------------- 1.3/12.8 MB 1.1 MB/s eta 0:00:11
#      ---- ----------------------------------- 1.6/12.8 MB 1.2 MB/s eta 0:00:10
#      ----- ---------------------------------- 1.8/12.8 MB 1.1 MB/s eta 0:00:10
#      ------ --------------------------------- 2.1/12.8 MB 1.2 MB/s eta 0:00:10
#      -------- ------------------------------- 2.6/12.8 MB 1.2 MB/s eta 0:00:09
#      -------- ------------------------------- 2.6/12.8 MB 1.2 MB/s eta 0:00:09
#      --------- ------------------------------ 2.9/12.8 MB 1.2 MB/s eta 0:00:09
#      ---------- ----------------------------- 3.4/12.8 MB 1.2 MB/s eta 0:00:08
#      ----------- ---------------------------- 3
1 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 1.1 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 1.1 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# ## Connect OpenSearch

# %%
#Connect to the running OpenSearch cluster
from opensearchpy import OpenSearch

client = OpenSearch(
    hosts=[{"host": "localhost", "port": 9200}],
    http_compress=True,
    use_ssl=False,
    verify_certs=False
)

# Test connection
print(client.info())
# Out:
# {'name': 'opensearch-node1', 'cluster_name': 'opensearch-cluster', 'cluster_uuid': 'WHW2Xt5vQfqBA9trb4dorg', 'version': {'distribution': 'opensearch', 'number': '3.3.2', 'build_type': 'tar', 'build_hash': '6564992150e26aaa62d4522a220dfff5188aeb88', 'build_date': '2025-10-29T22:24:07.450919802Z', 'build_snapshot': False, 'lucene_version': '10.3.1', 'minimum_wire_compatibility_version': '2.19.0', 'minimum_index_compatibility_version': '2.0.0'}, 'tagline': 'The OpenSearch Project: https://opensearch.org/'}

# %%
from bs4 import BeautifulSoup
import os, re
import spacy
import dateparser
from opensearchpy import OpenSearch
from geopy.geocoders import Nominatim
from opensearchpy.helpers import bulk

# %% [markdown]
# ## Create Index With Correct Mappings + Analyzers

# %%
index_name = "index"

mapping = {
    "settings": {
        "number_of_shards": 1,
        "number_of_replicas": 0,
        "analysis": {
            "analyzer": {
                "autocomplete_analyzer": {
                    "type": "custom",
                    "tokenizer": "standard",
                    "filter": ["lowercase", "autocomplete_filter"]
                }
            },
            "filter": {
                "autocomplete_filter": {
                    "type": "edge_ngram",
                    "min_gram": 3,
                    "max_gram": 20
                }
            }
        }
    },
    "mappings": {
        "properties": {
            "title": {
                "type": "text",
                "analyzer": "autocomplete_analyzer",
                "search_analyzer": "standard"
            },
            "content": {
                "type": "text",
                "analyzer": "standard"
            },
            "authors": {
                "type": "nested",
                "properties": {
                    "first_name": {"type": "text"},
                    "last_name": {"type": "text"},
                    "email": {"type": "keyword"}
                }
            },
            "date": {"type": "date"},
            "geopoint": {"type": "geo_point"},
            "temporal_expressions": {"type": "date"},  # array of extracted dates
            "georeferences": {"type": "geo_point"}     # array of extracted locations
        }
    }
}

# Create index
if not client.indices.exists(index=index_name):
    client.indices.create(index=index_name, body=mapping)
    print(f"Index '{index_name}' created successfully")
else:
    print(f"Index '{index_name}' already exists")
# Out:
# Index 'index' created successfully

# %%
import spacy
from dateparser import parse as parse_date
from geopy.geocoders import Nominatim

nlp = spacy.load("en_core_web_sm")
geolocator = Nominatim(user_agent="smart_doc_system")

def extract_temporal(text):
    doc = nlp(text)
    dates = []
    for ent in doc.ents:
        if ent.label_ == "DATE":
            parsed = parse_date(ent.text)
            if parsed:
                dates.append(parsed)
    return dates

def extract_georeferences(text):
    doc = nlp(text)
    coords = []
    for ent in doc.ents:
        if ent.label_ in ["GPE", "LOC"]:
            location = geolocator.geocode(ent.text)
            if location:
                coords.append({"lat": location.latitude, "lon": location.longitude})
    return coords

# Example indexing function
def index_document(doc_id, title, content, authors, date=None, geopoint=None):
    temporal_expressions = extract_temporal(content)
    georeferences = extract_georeferences(content)

    # Use extracted temporal/geopoint if original is missing
    doc_body = {
        "title": title,
        "content": content,
        "authors": authors,
        "date": date or (temporal_expressions[0] if temporal_expressions else None),
        "geopoint": geopoint or (georeferences[0] if georeferences else None),
        "temporal_expressions": temporal_expressions,
        "georeferences": georeferences
    }

    client.index(index=index_name, id=doc_id, body=doc_body)

# %% [markdown]
# ## Load & Parse Documents (SGML / HTML)
